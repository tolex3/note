# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pymc as pm

# %%
from graphviz import Digraph

# %%
dot = Digraph()
'''
dot.node('D','Dead')
dot.node('P','Pop')
dot.node('A','Age')
dot.node('H','Health_Level')
dot.node('M','Medical_Care')
dot.node('E','Elderly_Care')
dot.node('ee','Economy')
dot.node('a','Automation')
dot.node('B','Births')
dot.node('e','Education')
dot.node('m','Migration')
dot.node('G','Gvmt_Response')
dot.node('d','Density')
dot.node('I','Interactions')
dot.node('b','Behavioral_Patterns')
dot.node('F','Family_Structure')
dot.node('P','Prev_Flu_Season')
dot.node('S','Season')
dot.node('L','Latitude')
'''

dot.edge('Pop','Dead')
dot.edge('Pop','Density')
dot.edge('Pop','Births')
dot.edge('Pop','Economy')
dot.edge('Pop','Density')
dot.edge('Pop','Interactions')
dot.edge('Age','Dead')
dot.edge('Health_Level','Dead')
dot.edge('Migration','Health_Level')
dot.edge('Medical_Care','Health_Level')
dot.edge('Medical_Care','Dead')
dot.edge('Health_Level','Age')
dot.edge('Age','Medical_Care')
dot.edge('Age','Elderly_Care')
dot.edge('Age','Economy')
dot.edge('Age','Births')
dot.edge('Health_Level','Pop')
dot.edge('Health_Level','Medical_Care')
dot.edge('Health_Level','Elderly_Care')
dot.edge('Health_Level','Economy')
dot.edge('Medical_Care','Elderly_Care')
dot.edge('Medical_Care','Gvmt_Response')
dot.edge('Elderly_Care','Pop')
dot.edge('Elderly_Care','Dead')
dot.edge('Elderly_Care','Age')
dot.edge('Elderly_Care','Behavioral_Patterns')
dot.edge('Elderly_Care','Medical_Care')
dot.edge('Elderly_Care','Health_Level')
dot.edge('Elderly_Care','Gvmt_Response')
dot.edge('Economy','Dead')
dot.edge('Economy','Health_Level')
dot.edge('Economy','Medical_Care')
dot.edge('Economy','Elderly_Care')
dot.edge('Economy','Education')
dot.edge('Economy','Migration')
dot.edge('Economy','Pop')
dot.edge('Economy','Age')
dot.edge('Automation','Economy')
dot.edge('Automation','Health_Level')
dot.edge('Automation','Medical_Care')
dot.edge('Automation','Education')
dot.edge('Automation','Interactions')
dot.edge('Births','Pop')
dot.edge('Education','Economy')
dot.edge('Education','Automation')
dot.edge('Migration','Pop')
dot.edge('Migration','Age')
dot.edge('Migration','Dead')
dot.edge('Migration','Economy')
dot.edge('Migration','Education')
dot.edge('Migration','Interactions')
dot.edge('Migration','Behavioral_Patterns')
dot.edge('Migration','Births')
dot.edge('Migration','Family_Structure')
dot.edge('Gvmt_Response','Interactions')
dot.edge('Gvmt_Response','Economy')
dot.edge('Gvmt_Response','Health_Level')
dot.edge('Gvmt_Response','Dead')
dot.edge('Gvmt_Response','Medical_Care')
dot.edge('Density','Interactions')
dot.edge('Density','Behavioral_Patterns')
dot.edge('Density','Family_Structure')
dot.edge('Density','Dead')
dot.edge('Interactions','Dead')
dot.edge('Interactions','Behavioral_Patterns')
dot.edge('Behavioral_Patterns','Dead')
dot.edge('Behavioral_Patterns','Interactions')
dot.edge('Behavioral_Patterns','Medical_Care')
dot.edge('Family_Structure','Behavioral_Patterns')
dot.edge('Family_Structure','Interactions')
dot.edge('Family_Structure','Dead')
dot.edge('Prev_Flu_Season','Dead')
dot.edge('Season','Dead')
dot.edge('Latitude','Dead')


dot.edge('Gvmt_Response','Dead',color='red')


dot.format='jpg'
dot.render('foo.jpg',renderer='gd')
